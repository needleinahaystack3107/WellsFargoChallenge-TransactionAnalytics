# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Section 1: Exploratory Data Analysis
# This section of the notebook encompasses loading the training dataset and visualizing the summary statistics around the dataset. An understanding of the training and testing shape and distribution helps us understand key worksteps that we would need to take before beginning feature engineering and pre processing.

# %%
train_df = pd.read_excel("C:/Users/abhij/Git Repos/WellsFargoChallenge-TransactionAnalytics/train.xlsx")
test_df = pd.read_excel("C:/Users/abhij/Git Repos/WellsFargoChallenge-TransactionAnalytics/test.xlsx")
train_df.head(5)
# Out:
#   sor                cdf_seq_no  \
# 0  HH        T20110701260061756
# 1  HH       T201302289909010349
# 2  HH  T20130726991361190114550
# 3  BK       T201207095780929968
# 4  HH  T20131230990558080004939
#
#                                           trans_desc  merchant_cat_code  \
# 0  RECUR DEBIT CRD PMT11/11 DELTA DENTAL OF A11 O...             6300.0
# 1  CHECK CRD PURCHASE 11/11 SURETY SOLUTIONS,    ...                NaN
# 2  CHECK CRD PURCHASE 11/11 THE COPY STOP        ...                NaN
# 3           MARKET ALERT INC         111-111-1111 TX             7375.0
# 4  CHECK CRD PURCHASE 11/11 PERT- NER PERFECT    ...                NaN
#
#       amt db_cr_cd payment_reporting_category payment_category  \
# 0   58.34        D                       Card       Debit Card
# 1  103.00        D                       Card       Check Card
# 2   22.44        D                       Card       Check Card
# 3   22.44      NaN                       Card      Credit Card
# 4   66.25        D                       Card       Check Card
#
#    is_international           default_brand  default_location  \
# 0             False  DELTA DENTAL OF A11 OF    111-1111111 AR
# 1             False       SURETY SOLUTIONS,   111-111-1111 OR
# 2             False           THE COPY STOP  SALT LAKE CIT UT
# 3             False        MARKET ALERT INC   111-111-1111 TX
# 4             False       PERT- NER PERFECT  THE WOODLANDS TX
#
#                   qrated_brand              coalesced_brand Category
# 0                 Delta Dental                 Delta Dental  Finance
# 1             Surety Solutions             Surety Solutions  Finance
# 2                The Copy Stop                The Copy Stop  Finance
# 3                 Market Alert                 Market Alert  Finance
# 4  Hometown Insurance Partners  Hometown Insurance Partners  Finance

# %%
test_df.head(5)
# Out:
#   sor                cdf_seq_no  \
# 0  HH  T20131230990668080055738
# 1  HH       T201302289918775816
# 2  HH  T20130726991361190218055
# 3  HH       T201208319924922772
# 4  HH  T20131230990638080027066
#
#                                           trans_desc  merchant_cat_code  \
# 0  CHECK CRD PURCHASE 11/11 PACKAGE EXPRESS      ...                NaN
# 1  RECUR DEBIT CRD PMT11/11 YP *FRMLY AT&T AD    ...                NaN
# 2  CHECK CRD PURCHASE 11/11 NORMAN G JENSEN IN   ...                NaN
# 3  CHECK CRD PUR RTRN 11/11 TWILIO               ...                NaN
# 4  CHECK CRD PURCHASE 11/11 AT&T D11K 1111       ...                NaN
#
#       amt db_cr_cd payment_reporting_category payment_category  \
# 0   10.35        D                       Card       Check Card
# 1   36.00        D                       Card       Debit Card
# 2   27.00        D                       Card       Check Card
# 3   20.00        C                       Card       Check Card
# 4  325.78        D                       Card       Check Card
#
#    is_international       default_brand  default_location     qrated_brand  \
# 0             False     PACKAGE EXPRESS          LACEY WA  Package Express
# 1             False   YP *FRMLY AT&T AD   111-111-1111 CA         At And T
# 2             False  NORMAN G JENSEN IN    111-1111111 MN  Norman G Jensen
# 3             False              TWILIO  SAN FARANSICO CA           Twilio
# 4             False      AT&T D11K 1111     FORT WORTH TX         At And T
#
#    coalesced_brand  Category
# 0  Package Express       NaN
# 1         At And T       NaN
# 2  Norman G Jensen       NaN
# 3           Twilio       NaN
# 4         At And T       NaN

# %%
test_df.shape
# Out:
# (10000, 14)

# %% [markdown]
# An important thing to note is that the target feature is present in the test dataset as an empty column

# %%
train_df.describe()
# Out:
#        merchant_cat_code           amt
# count       24691.000000  40000.000000
# mean         6263.878134     75.870519
# std          1217.403683    254.587351
# min             0.000000      0.010000
# 25%          5699.000000     14.007500
# 50%          5814.000000     29.990000
# 75%          7230.000000     63.650000
# max          9405.000000  23313.800000

# %%
test_df.describe()
# Out:
#        merchant_cat_code           amt  Category
# count        6287.000000  10000.000000       0.0
# mean         6281.211707     76.203879       NaN
# std          1239.748198    269.585852       NaN
# min           742.000000      0.010000       NaN
# 25%          5699.000000     14.000000       NaN
# 50%          5814.000000     29.955000       NaN
# 75%          7298.000000     62.602500       NaN
# max          9399.000000  12537.330000       NaN

# %% [markdown]
# The distribution of amounts seem to be similar overall for train and test datasets. Below are the features and the type of features for the modelling problem:

# %%
print(train_df.dtypes)
# Out:
# sor                            object
# cdf_seq_no                     object
# trans_desc                     object
# merchant_cat_code             float64
# amt                           float64
# db_cr_cd                       object
# payment_reporting_category     object
# payment_category               object
# is_international                 bool
# default_brand                  object
# default_location               object
# qrated_brand                   object
# coalesced_brand                object
# Category                       object
# dtype: object

# %%
train_df['db_cr_cd'].value_counts()
# Out:
# D    37962
# C     1726
# Name: db_cr_cd, dtype: int64

# %%
# Creating a function to view target distribution by a column
def tgt_dist(df,target,col_name):
    df = pd.crosstab(index=df[col_name], 
                             columns=train_df[target],
                             margins=True).sort_values(by = 'All', ascending=False).head(20)

    return df

# %%
train_df.columns
# Out:
# Index(['sor', 'cdf_seq_no', 'trans_desc', 'merchant_cat_code', 'amt',
#        'db_cr_cd', 'payment_reporting_category', 'payment_category',
#        'is_international', 'default_brand', 'default_location', 'qrated_brand',
#        'coalesced_brand', 'Category'],
#       dtype='object')

# %%
cross = pd.crosstab(index=train_df["default_brand"], 
                             columns=train_df["Category"],
                             margins=True).sort_values(by = 'All', ascending=False).head(20)

cross
# Out:
# Category                Communication Services  Education  Entertainment  \
# default_brand
# All                                        282        445          11255
# CVS PHARMACY #1111                           0          0              0
# WALGREENS #1111                              0          0              0
# LIVINGSOCIAL*                                0          0              0
# American Ski Exchange                        0          0              0
# MSL MAIN CENTRAL A                           0          0              0
# MOXIES CLASSIC GRILL #                       0          0              2
# MOO INC PRINTING                             0          0              0
# MONTE CARLO FRONT DESK                       0          0              0
# TWX*GOLF MAGAZINE                            0          0              0
# MOMS ON THE RUN LLC                          0          0              0
# MOM'S PIE HOUSE - JULI                       0          0              2
# The Tog Shop                                 0          0              0
# Amazon Video On Demand                       0          0              0
# BASIL'S TAILOR SHOP                          0          0              0
# Amazon Digital Svcs                          0          0              0
# ISKIN                                        0          0              0
# AZ STATE CAPITL MUSEUM                       0          0              2
# AVID PETTRAC                                 0          0              0
# IVYMEDIA DBA GOTOBUS                         0          0              0
#
# Category                Finance  Health and Community Services  \
# default_brand
# All                         185                           4157
# CVS PHARMACY #1111            0                              0
# WALGREENS #1111               0                              0
# LIVINGSOCIAL*                 0                              0
# American Ski Exchange         0                              0
# MSL MAIN CENTRAL A            0                              0
# MOXIES CLASSIC GRILL #        0                              0
# MOO INC PRINTING              0                              0
# MONTE CARLO FRONT DESK        0                              0
# TWX*GOLF MAGAZINE             0                              0
# MOMS ON THE RUN LLC           0                              2
# MOM'S PIE HOUSE - JULI        0                              0
# The Tog Shop                  0                              0
# Amazon Video On Demand        0                              0
# BASIL'S TAILOR SHOP           0                              0
# Amazon Digital Svcs           0                              0
# ISKIN                         0                              0
# AZ STATE CAPITL MUSEUM        0                              0
# AVID PETTRAC                  0                              2
# IVYMEDIA DBA GOTOBUS          0                              0
#
# Category                Property and Business Services  Retail Trade  \
# default_brand
# All                                               1095         13500
# CVS PHARMACY #1111                                   0             3
# WALGREENS #1111                                      0             3
# LIVINGSOCIAL*                                        0             3
# American Ski Exchange                                0             2
# MSL MAIN CENTRAL A                                   0             2
# MOXIES CLASSIC GRILL #                               0             0
# MOO INC PRINTING                                     2             0
# MONTE CARLO FRONT DESK                               0             0
# TWX*GOLF MAGAZINE                                    2             0
# MOMS ON THE RUN LLC                                  0             0
# MOM'S PIE HOUSE - JULI                               0             0
# The Tog Shop                                         0             2
# Amazon Video On Demand                               0             2
# BASIL'S TAILOR SHOP                                  0             0
# Amazon Digital Svcs                                  0             2
# ISKIN                                                0             2
# AZ STATE CAPITL MUSEUM                               0             0
# AVID PETTRAC                                         0             0
# IVYMEDIA DBA GOTOBUS                                 0             0
#
# Category                Services to Transport  \
# default_brand
# All                                      2317
# CVS PHARMACY #1111                          0
# WALGREENS #1111                             0
# LIVINGSOCIAL*                               0
# American Ski Exchange                       0
# MSL MAIN CENTRAL A                          0
# MOXIES CLASSIC GRILL #                      0
# MOO INC PRINTING                            0
# MONTE CARLO FRONT DESK                      0
# TWX*GOLF MAGAZINE                           0
# MOMS ON THE RUN LLC                         0
# MOM'S PIE HOUSE - JULI                      0
# The Tog Shop                                0
# Amazon Video On Demand                      0
# BASIL'S TAILOR SHOP                         0
# Amazon Digital Svcs                         0
# ISKIN                                       0
# AZ STATE CAPITL MUSEUM                      0
# AVID PETTRAC                                0
# IVYMEDIA DBA GOTOBUS                        0
#
# Category                Trade, Professional and Personal Services  Travel  \
# default_brand
# All                                                          5275    1489
# CVS PHARMACY #1111                                              0       0
# WALGREENS #1111                                                 0       0
# LIVINGSOCIAL*                                                   0       0
# American Ski Exchange                                           0       0
# MSL MAIN CENTRAL A                                              0       0
# MOXIES CLASSIC GRILL #                                          0       0
# MOO INC PRINTING                                                0       0
# MONTE CARLO FRONT DESK                                          0       2
# TWX*GOLF MAGAZINE                                               0       0
# MOMS ON THE RUN LLC                                             0       0
# MOM'S PIE HOUSE - JULI                                          0       0
# The Tog Shop                                                    0       0
# Amazon Video On Demand                                          0       0
# BASIL'S TAILOR SHOP                                             2       0
# Amazon Digital Svcs                                             0       0
# ISKIN                                                           0       0
# AZ STATE CAPITL MUSEUM                                          0       0
# AVID PETTRAC                                                    0       0
# IVYMEDIA DBA GOTOBUS                                            0       2
#
# Category                  All
# default_brand
# All                     40000
# CVS PHARMACY #1111          3
# WALGREENS #1111             3
# LIVINGSOCIAL*               3
# American Ski Exchange       2
# MSL MAIN CENTRAL A          2
# MOXIES CLASSIC GRILL #      2
# MOO INC PRINTING            2
# MONTE CARLO FRONT DESK      2
# TWX*GOLF MAGAZINE           2
# MOMS ON THE RUN LLC         2
# MOM'S PIE HOUSE - JULI      2
# The Tog Shop                2
# Amazon Video On Demand      2
# BASIL'S TAILOR SHOP         2
# Amazon Digital Svcs         2
# ISKIN                       2
# AZ STATE CAPITL MUSEUM      2
# AVID PETTRAC                2
# IVYMEDIA DBA GOTOBUS        2

# %% [markdown]
# #### Important Features by intuition
# * Payment Category
# * db_cr_cd
# * default_brand

# %%
sample_desc = train_df.head(100).iloc[60,2]
sample_desc
# Out:
# 'CHECK CRD PURCHASE 11/11 COUNTRY OAKS RV MOBILE  111-111-1111  LA 111111XXXXXX1111 111111111111111                               ?MCC=1111 11'

# %% [markdown]
# Many of the transaction descriptions have ones and random information that do not seem of relevance. Removing them before further steps of extracting features seem to be required before further modelling. Lets define a function that removes these unrequired tokens.

# %% [markdown]
# ## Data Cleaning and Preprocessing
#
# This section of the notebook focuses on removing unrelated text to the problem statement. All transaction descriptions are then converted to lower text. to avoid redundancies during tokenization and word extraction. Finally, each transaction category which is the target variable is converted to a numerical value between 0 to 9.
#
# 1. We first remove unwanted text(various combinations of 1s) found in transaction descriptions and default location.

# %%
def oneremover(df):
    desc_series = list(df['trans_desc'])
    for item in range(len(desc_series)):
        desc_series[item] = re.sub(" +", " ", desc_series[item])
        desc_series[item] = re.sub("111111XXXXXX1111 111111111111111", "", desc_series[item])
        desc_series[item] = re.sub("\?MCC=1111 11", "", desc_series[item])
        desc_series[item] = re.sub("111-111-1111", " ", desc_series[item])
        desc_series[item] = re.sub("111-1111111", "", desc_series[item])
        desc_series[item] = re.sub("11111", "", desc_series[item])
        desc_series[item] = re.sub("\?MCC=1111", "", desc_series[item])
        
    # Cleaning default location    
    desc_series_location = list(df['default_location'])
    desc_series_location = [str(p) for p in desc_series_location]
    for item in range(len(desc_series_location)):
        desc_series_location[item] = re.sub("111-111-1111", "", desc_series[item])
        desc_series_location[item] = re.sub("111-1111111", "", desc_series[item])
        desc_series_location[item] = re.sub("11111", "", desc_series[item])
        
    
        
    for index, row in df.iterrows():
        df.at[index, 'trans_desc'] = desc_series[index]
        df.at[index, 'default_location'] = desc_series[index]
    return df

# %%
train_df = oneremover(train_df)
train_df
# Out:
#       sor                cdf_seq_no  \
# 0      HH        T20110701260061756
# 1      HH       T201302289909010349
# 2      HH  T20130726991361190114550
# 3      BK       T201207095780929968
# 4      HH  T20131230990558080004939
# ...    ..                       ...
# 39995  HH  T20130726991321130015959
# 39996  HH       T201208319925685298
# 39997  HH        T20111004560028307
# 39998  HH        T20110601320040304
# 39999  HH       T201208319925581644
#
#                                               trans_desc  merchant_cat_code  \
# 0      RECUR DEBIT CRD PMT11/11 DELTA DENTAL OF A11 O...             6300.0
# 1      CHECK CRD PURCHASE 11/11 SURETY SOLUTIONS,   OR                  NaN
# 2      CHECK CRD PURCHASE 11/11 THE COPY STOP SALT LA...                NaN
# 3                                  MARKET ALERT INC   TX             7375.0
# 4      CHECK CRD PURCHASE 11/11 PERT- NER PERFECT THE...                NaN
# ...                                                  ...                ...
# 39995  CHECK CRD PURCHASE 11/11 ALLIED FIDELITY SE   ...                NaN
# 39996  CHECK CRD PURCHASE 11/11 FOREMOST INSURANCE  MI                  NaN
# 39997  CHECK CRD PURCHASE 11/11 PROPAY USA- ProPay, I...             7399.0
# 39998  CHECK CRD PURCHASE 11/11 COWBOY FINANCE LLC  NM               6051.0
# 39999  CHECK CRD PURCHASE 11/11 JONJON DELI GROCER BR...                NaN
#
#           amt db_cr_cd payment_reporting_category payment_category  \
# 0       58.34        D                       Card       Debit Card
# 1      103.00        D                       Card       Check Card
# 2       22.44        D                       Card       Check Card
# 3       22.44      NaN                       Card      Credit Card
# 4       66.25        D                       Card       Check Card
# ...       ...      ...                        ...              ...
# 39995  100.00        D                       Card       Check Card
# 39996  184.78        D                       Card       Check Card
# 39997    9.95        D                       Card       Check Card
# 39998  250.00        D                       Card       Check Card
# 39999   14.49        D                       Card       Check Card
#
#        is_international           default_brand  \
# 0                 False  DELTA DENTAL OF A11 OF
# 1                 False       SURETY SOLUTIONS,
# 2                 False           THE COPY STOP
# 3                 False        MARKET ALERT INC
# 4                 False       PERT- NER PERFECT
# ...                 ...                     ...
# 39995             False      ALLIED FIDELITY SE
# 39996             False      FOREMOST INSURANCE
# 39997             False  PROPAY USA- ProPay, In
# 39998             False      COWBOY FINANCE LLC
# 39999             False      JONJON DELI GROCER
#
#                                         default_location  \
# 0      RECUR DEBIT CRD PMT11/11 DELTA DENTAL OF A11 O...
# 1      CHECK CRD PURCHASE 11/11 SURETY SOLUTIONS,   OR
# 2      CHECK CRD PURCHASE 11/11 THE COPY STOP SALT LA...
# 3                                  MARKET ALERT INC   TX
# 4      CHECK CRD PURCHASE 11/11 PERT- NER PERFECT THE...
# ...                                                  ...
# 39995  CHECK CRD PURCHASE 11/11 ALLIED FIDELITY SE   ...
# 39996  CHECK CRD PURCHASE 11/11 FOREMOST INSURANCE  MI
# 39997  CHECK CRD PURCHASE 11/11 PROPAY USA- ProPay, I...
# 39998  CHECK CRD PURCHASE 11/11 COWBOY FINANCE LLC  NM
# 39999  CHECK CRD PURCHASE 11/11 JONJON DELI GROCER BR...
#
#                       qrated_brand              coalesced_brand Category
# 0                     Delta Dental                 Delta Dental  Finance
# 1                 Surety Solutions             Surety Solutions  Finance
# 2                    The Copy Stop                The Copy Stop  Finance
# 3                     Market Alert                 Market Alert  Finance
# 4      Hometown Insurance Partners  Hometown Insurance Partners  Finance
# ...                            ...                          ...      ...
# 39995         Fidelity Investments         Fidelity Investments  Finance
# 39996           Foremost Insurance           Foremost Insurance  Finance
# 39997                       Propay                       Propay  Finance
# 39998               Cowboy Finance               Cowboy Finance  Finance
# 39999                  Deli Grocer                  Deli Grocer  Finance
#
# [40000 rows x 14 columns]

# %%
train_df['trans_desc']
# Out:
# 0        RECUR DEBIT CRD PMT11/11 DELTA DENTAL OF A11 O...
# 1        CHECK CRD PURCHASE 11/11 SURETY SOLUTIONS,   OR
# 2        CHECK CRD PURCHASE 11/11 THE COPY STOP SALT LA...
# 3                                    MARKET ALERT INC   TX
# 4        CHECK CRD PURCHASE 11/11 PERT- NER PERFECT THE...
#                                ...
# 39995    CHECK CRD PURCHASE 11/11 ALLIED FIDELITY SE   ...
# 39996    CHECK CRD PURCHASE 11/11 FOREMOST INSURANCE  MI
# 39997    CHECK CRD PURCHASE 11/11 PROPAY USA- ProPay, I...
# 39998    CHECK CRD PURCHASE 11/11 COWBOY FINANCE LLC  NM
# 39999    CHECK CRD PURCHASE 11/11 JONJON DELI GROCER BR...
# Name: trans_desc, Length: 40000, dtype: object

# %% [markdown]
# ## Baseline Modelling
# ** without any Feature Engineering or Data Cleaning

# %%
## Tokenization
